# %%
import time
import json
import pandas as pd
import requests
from requests.auth import HTTPBasicAuth

ts = int(time.time()) * 1000
URL_TS = ts - (60 * 60 * 1000)
    
url = 'https://mapr-web.advantagedp.org:20202/ws/v1/cluster/apps?user=ingest_pipeline-s&finalStatus=SUCCEEDED&startedTimeBegin=1568491200000'
url2 = 'https://mapr-web.advantagedp.org:20202/ws/v1/cluster/apps?user=session_checker-s&finalStatus=SUCCEEDED&finishedTimeBegin=1568491200000'
auth = HTTPBasicAuth('ingest_pipeline-s', '1Rt.d5WssojT.2')
auth2 = HTTPBasicAuth('session_checker-s', 'ohydn6-20DfJq_ZW')
proxies = {'http': 'socks5h://192.168.67.2:1081', 'https': 'socks5h://192.168.67.2:1081'}

# %%
requests.urllib3.disable_warnings()

# %%
response = requests.get(url, auth=auth, proxies=proxies, verify=False)
response_json = response.json()
response2 = requests.get(url2, auth=auth2, proxies=proxies, verify=False)
response2_json = response2.json()
response
# Out:
# <Response [200]>

# %%
response2_json
# Out:
# {'apps': {'app': [{'id': 'application_1660460142322_623729',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623729/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '7d85f4bc49a54fd295411ea7054153af',
#     'startedTime': 1662001352433,
#     'finishedTime': 1662002883226,
#     'elapsedTime': 1530793,
#     'amContainerLogs': 'https://bmwdpdesp000199.advantagedp.org:8044/node/containerlogs/container_1660460142322_623729_01_000001/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000199.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 5250992462,
#     'vcoreSeconds': 367139,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_622927',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_622927/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'caef978edb784705a99b536d7c2f340d',
#     'startedTime': 1661999168824,
#     'finishedTime': 1662001266132,
#     'elapsedTime': 2097308,
#     'amContainerLogs': 'https://bmwdpdesp000326.advantagedp.org:8044/node/containerlogs/container_1660460142322_622927_01_000002/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000326.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 7462545373,
#     'vcoreSeconds': 521762,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_624814',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_624814/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '5ddab2a5a8ac40738cd1b6857759e6a3',
#     'startedTime': 1662004215350,
#     'finishedTime': 1662005902557,
#     'elapsedTime': 1687207,
#     'amContainerLogs': 'https://bmwdpdesp000355.advantagedp.org:8044/node/containerlogs/container_1660460142322_624814_01_000001/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000355.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 5901163490,
#     'vcoreSeconds': 412596,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_624311',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_624311/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'b466e4663ad24969b54713af5a308faf',
#     'startedTime': 1662002967782,
#     'finishedTime': 1662004137767,
#     'elapsedTime': 1169985,
#     'amContainerLogs': 'https://bmwdpdesp000058.advantagedp.org:8044/node/containerlogs/container_1660460142322_624311_01_000002/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000058.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 4091817479,
#     'vcoreSeconds': 285999,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_631343',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob-reingest',
#     'queue': 'root.projects_irregular.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_631343/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '',
#     'startedTime': 1662016431970,
#     'finishedTime': 1662018345643,
#     'elapsedTime': 1913673,
#     'amContainerLogs': 'https://bmwdpdesp000133.advantagedp.org:8044/node/containerlogs/container_1660460142322_631343_01_000003/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000133.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 6774942674,
#     'vcoreSeconds': 473656,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_627664',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_627664/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '060ef3c185d94446b099b120e09b5569',
#     'startedTime': 1662010654741,
#     'finishedTime': 1662012774702,
#     'elapsedTime': 2119961,
#     'amContainerLogs': 'https://bmwdpdesp000033.advantagedp.org:8044/node/containerlogs/container_1660460142322_627664_01_000002/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000033.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 7535600831,
#     'vcoreSeconds': 526844,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626919',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626919/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'ffacbe8b7a02473d9f9b8c40e02e712a',
#     'startedTime': 1662008905209,
#     'finishedTime': 1662010571758,
#     'elapsedTime': 1666549,
#     'amContainerLogs': 'https://bmwdpdesp000281.advantagedp.org:8044/node/containerlogs/container_1660460142322_626919_01_000003/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000281.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 5927048241,
#     'vcoreSeconds': 414398,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_625807',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_625807/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'd604df31eead49f583cc693c010c8d64',
#     'startedTime': 1662005997293,
#     'finishedTime': 1662007391948,
#     'elapsedTime': 1394655,
#     'amContainerLogs': 'https://bmwdpdesp000157.advantagedp.org:8044/node/containerlogs/container_1660460142322_625807_01_000001/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000157.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 4714016431,
#     'vcoreSeconds': 329600,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626371',
#     'user': 'session_checker-s',
#     'name': 'SessionCheckerJob',
#     'queue': 'root.projects.project_session_checker',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626371/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '589c0f8febce49d19c77feac0e212bb9',
#     'startedTime': 1662007481966,
#     'finishedTime': 1662008812757,
#     'elapsedTime': 1330791,
#     'amContainerLogs': 'https://bmwdpdesp000343.advantagedp.org:8044/node/containerlogs/container_1660460142322_626371_01_000001/session_checker-s',
#     'amHostHttpAddress': 'bmwdpdesp000343.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 4686486290,
#     'vcoreSeconds': 327672,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0}]}}

# %%
response_json
# Out:
# {'apps': {'app': [{'id': 'application_1660460142322_623414',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623414/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'a8ab12a349a24c7f98e980eb257d0230',
#     'startedTime': 1662000538435,
#     'finishedTime': 1662000637740,
#     'elapsedTime': 99305,
#     'amContainerLogs': 'https://bmwdpdesp000249.advantagedp.org:8044/node/containerlogs/container_1660460142322_623414_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000249.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 3823128,
#     'vcoreSeconds': 1771,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623413',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623413/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'f21186dafdac4b56ab0e951810a51183',
#     'startedTime': 1662000538029,
#     'finishedTime': 1662000620182,
#     'elapsedTime': 82153,
#     'amContainerLogs': 'https://bmwdpdesp000305.advantagedp.org:8044/node/containerlogs/container_1660460142322_623413_01_000003/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000305.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 6241429,
#     'vcoreSeconds': 2997,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623415',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623415/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'ea195cdb2b364fbf8684d6d24069290e',
#     'startedTime': 1662000538150,
#     'finishedTime': 1662000636527,
#     'elapsedTime': 98377,
#     'amContainerLogs': 'https://bmwdpdesp000227.advantagedp.org:8044/node/containerlogs/container_1660460142322_623415_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000227.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 3853330,
#     'vcoreSeconds': 1810,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623398',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623398/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '436df774a6af42338ad5f08894455f00',
#     'startedTime': 1662000497363,
#     'finishedTime': 1662000674986,
#     'elapsedTime': 177623,
#     'amContainerLogs': 'https://bmwdpdesp000046.advantagedp.org:8044/node/containerlogs/container_1660460142322_623398_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000046.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 16396842,
#     'vcoreSeconds': 7876,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623397',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623397/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'a99eadf6a1bf452682dd1fcb6cb1ad68',
#     'startedTime': 1662000497050,
#     'finishedTime': 1662000639659,
#     'elapsedTime': 142609,
#     'amContainerLogs': 'https://bmwdpdesp000180.advantagedp.org:8044/node/containerlogs/container_1660460142322_623397_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000180.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 9538685,
#     'vcoreSeconds': 4541,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623396',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623396/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '4f55dafac0ad4a2e9d9aca681714093e',
#     'startedTime': 1662000496809,
#     'finishedTime': 1662000628784,
#     'elapsedTime': 131975,
#     'amContainerLogs': 'https://bmwdpdesp000358.advantagedp.org:8044/node/containerlogs/container_1660460142322_623396_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000358.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 6457567,
#     'vcoreSeconds': 3080,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623401',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623401/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'bb7570032380432eb0bfdd1daf620de1',
#     'startedTime': 1662000497634,
#     'finishedTime': 1662000654906,
#     'elapsedTime': 157272,
#     'amContainerLogs': 'https://bmwdpdesp000360.advantagedp.org:8044/node/containerlogs/container_1660460142322_623401_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000360.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12568981,
#     'vcoreSeconds': 6019,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623400',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623400/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '406bff4e3b0342a481891990474f14a3',
#     'startedTime': 1662000497529,
#     'finishedTime': 1662000636281,
#     'elapsedTime': 138752,
#     'amContainerLogs': 'https://bmwdpdesp000062.advantagedp.org:8044/node/containerlogs/container_1660460142322_623400_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000062.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 8455781,
#     'vcoreSeconds': 4037,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623399',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623399/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '1b4569b077334dd79349cd5b3b593381',
#     'startedTime': 1662000496986,
#     'finishedTime': 1662000603533,
#     'elapsedTime': 106547,
#     'amContainerLogs': 'https://bmwdpdesp000050.advantagedp.org:8044/node/containerlogs/container_1660460142322_623399_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000050.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 4981128,
#     'vcoreSeconds': 2367,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623361',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_fcb5a7ca-a00e-44c0-a572-0182ee980f80',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623361/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '8abfcd41b6cd48d0867b8a63d6c52a3c',
#     'startedTime': 1662000373845,
#     'finishedTime': 1662000681227,
#     'elapsedTime': 307382,
#     'amContainerLogs': 'https://bmwdpdesp000082.advantagedp.org:8044/node/containerlogs/container_1660460142322_623361_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000082.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 62473505,
#     'vcoreSeconds': 30295,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623360',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623360/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '01d53a6720f643bfb8d3e35160dd560c',
#     'startedTime': 1662000373512,
#     'finishedTime': 1662000435405,
#     'elapsedTime': 61893,
#     'amContainerLogs': 'https://bmwdpdesp000352.advantagedp.org:8044/node/containerlogs/container_1660460142322_623360_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000352.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 11336910,
#     'vcoreSeconds': 5461,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623368',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_9a40cbe9-a6b7-4b15-abcd-0182eed9801d',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623368/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '98fb6ce85481465599ea0f8bd09855cf',
#     'startedTime': 1662000393009,
#     'finishedTime': 1662000631276,
#     'elapsedTime': 238267,
#     'amContainerLogs': 'https://bmwdpdesp000345.advantagedp.org:8044/node/containerlogs/container_1660460142322_623368_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000345.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 46773595,
#     'vcoreSeconds': 22664,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623347',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_fe4eb15b-2a4d-4a60-a56a-0182ee6c18a8',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623347/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'aba0f04dbf79488ab7f5fd48ee78c48e',
#     'startedTime': 1662000332083,
#     'finishedTime': 1662000466375,
#     'elapsedTime': 134292,
#     'amContainerLogs': 'https://bmwdpdesp000197.advantagedp.org:8044/node/containerlogs/container_1660460142322_623347_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000197.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 20067096,
#     'vcoreSeconds': 9689,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623346',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_fe4eb15b-2a4d-4a60-a56a-0182ee6c18a8',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623346/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '3e4d8a2f05f74cb48d8c2699afd1c92a',
#     'startedTime': 1662000331684,
#     'finishedTime': 1662000507841,
#     'elapsedTime': 176157,
#     'amContainerLogs': 'https://bmwdpdesp000067.advantagedp.org:8044/node/containerlogs/container_1660460142322_623346_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000067.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 27871893,
#     'vcoreSeconds': 13455,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623344',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_fe4eb15b-2a4d-4a60-a56a-0182ee6c18a8',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623344/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '2aad9246da0f4729888bf8bf72a5bd11',
#     'startedTime': 1662000331187,
#     'finishedTime': 1662000526864,
#     'elapsedTime': 195677,
#     'amContainerLogs': 'https://bmwdpdesp000236.advantagedp.org:8044/node/containerlogs/container_1660460142322_623344_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000236.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 32496054,
#     'vcoreSeconds': 15717,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623353',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623353/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '37ab8b349aa44a3594c67264beff1225',
#     'startedTime': 1662000350723,
#     'finishedTime': 1662000433858,
#     'elapsedTime': 83135,
#     'amContainerLogs': 'https://bmwdpdesp000092.advantagedp.org:8044/node/containerlogs/container_1660460142322_623353_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000092.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12582637,
#     'vcoreSeconds': 6066,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623332',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623332/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '2a75e3c4d9634376ad33272493c20229',
#     'startedTime': 1662000283002,
#     'finishedTime': 1662000377821,
#     'elapsedTime': 94819,
#     'amContainerLogs': 'https://bmwdpdesp000119.advantagedp.org:8044/node/containerlogs/container_1660460142322_623332_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000119.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 15823821,
#     'vcoreSeconds': 7625,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623341',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623341/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '83fe8055d88a44c2955b1575707ed4f9',
#     'startedTime': 1662000308885,
#     'finishedTime': 1662000432082,
#     'elapsedTime': 123197,
#     'amContainerLogs': 'https://bmwdpdesp000321.advantagedp.org:8044/node/containerlogs/container_1660460142322_623341_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000321.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 14499780,
#     'vcoreSeconds': 6963,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623542',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_fe4eb15b-2a4d-4a60-a56a-0182ee6c18a8',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623542/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'a521113c20c74c3f8d7794d2a234e281',
#     'startedTime': 1662000843159,
#     'finishedTime': 1662001199146,
#     'elapsedTime': 355987,
#     'amContainerLogs': 'https://bmwdpdesp000036.advantagedp.org:8044/node/containerlogs/container_1660460142322_623542_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000036.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 67773583,
#     'vcoreSeconds': 32863,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623508',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623508/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'b24fc12373bf4c90b3694b87bf86e622',
#     'startedTime': 1662000763785,
#     'finishedTime': 1662000833838,
#     'elapsedTime': 70053,
#     'amContainerLogs': 'https://bmwdpdesp000263.advantagedp.org:8044/node/containerlogs/container_1660460142322_623508_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000263.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 13470539,
#     'vcoreSeconds': 6495,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623503',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623503/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '30570a1158bd4c44b4314fd0f34cf797',
#     'startedTime': 1662000745773,
#     'finishedTime': 1662000854637,
#     'elapsedTime': 108864,
#     'amContainerLogs': 'https://bmwdpdesp000062.advantagedp.org:8044/node/containerlogs/container_1660460142322_623503_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000062.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 18629745,
#     'vcoreSeconds': 8997,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623502',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623502/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'b3d4b453332a4e82910b686c689a60c8',
#     'startedTime': 1662000745336,
#     'finishedTime': 1662000826579,
#     'elapsedTime': 81243,
#     'amContainerLogs': 'https://bmwdpdesp000041.advantagedp.org:8044/node/containerlogs/container_1660460142322_623502_01_000003/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000041.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12839489,
#     'vcoreSeconds': 6192,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623476',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_9a40cbe9-a6b7-4b15-abcd-0182eed9801d',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623476/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '9d0397e5785f476393195fca58a9b67e',
#     'startedTime': 1662000704843,
#     'finishedTime': 1662000995121,
#     'elapsedTime': 290278,
#     'amContainerLogs': 'https://bmwdpdesp000334.advantagedp.org:8044/node/containerlogs/container_1660460142322_623476_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000334.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 55904929,
#     'vcoreSeconds': 27105,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623475',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_9a40cbe9-a6b7-4b15-abcd-0182eed9801d',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623475/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '62cc58f5c514489ea361fcefff4f275d',
#     'startedTime': 1662000704825,
#     'finishedTime': 1662001160054,
#     'elapsedTime': 455229,
#     'amContainerLogs': 'https://bmwdpdesp000092.advantagedp.org:8044/node/containerlogs/container_1660460142322_623475_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000092.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 83269019,
#     'vcoreSeconds': 40380,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623474',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_9a40cbe9-a6b7-4b15-abcd-0182eed9801d',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623474/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '65a5735bdfb44d6aae468099f9337492',
#     'startedTime': 1662000704009,
#     'finishedTime': 1662001026342,
#     'elapsedTime': 322333,
#     'amContainerLogs': 'https://bmwdpdesp000191.advantagedp.org:8044/node/containerlogs/container_1660460142322_623474_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000191.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 62652392,
#     'vcoreSeconds': 30357,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623470',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623470/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '4d5820c819c446a7a2781b07023506a3',
#     'startedTime': 1662000682749,
#     'finishedTime': 1662000794453,
#     'elapsedTime': 111704,
#     'amContainerLogs': 'https://bmwdpdesp000112.advantagedp.org:8044/node/containerlogs/container_1660460142322_623470_01_000006/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000112.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 20674272,
#     'vcoreSeconds': 10002,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623442',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_fe4eb15b-2a4d-4a60-a56a-0182ee6c18a8',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623442/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '32a28bdd9e0e40fd8da303c48476bb2d',
#     'startedTime': 1662000604348,
#     'finishedTime': 1662000724775,
#     'elapsedTime': 120427,
#     'amContainerLogs': 'https://bmwdpdesp000079.advantagedp.org:8044/node/containerlogs/container_1660460142322_623442_01_000006/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000079.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 18544464,
#     'vcoreSeconds': 8909,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623427',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623427/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '9f30f298db9d4da1986e82c5692ac5c9',
#     'startedTime': 1662000559272,
#     'finishedTime': 1662000700886,
#     'elapsedTime': 141614,
#     'amContainerLogs': 'https://bmwdpdesp000245.advantagedp.org:8044/node/containerlogs/container_1660460142322_623427_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000245.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 14320803,
#     'vcoreSeconds': 6903,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623426',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623426/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'e04d4dfe1010485e8e632546e6fa4dee',
#     'startedTime': 1662000559057,
#     'finishedTime': 1662000693063,
#     'elapsedTime': 134006,
#     'amContainerLogs': 'https://bmwdpdesp000075.advantagedp.org:8044/node/containerlogs/container_1660460142322_623426_01_000008/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000075.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12877731,
#     'vcoreSeconds': 6181,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623425',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623425/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'bece85aea3014fe2ace93c399d381954',
#     'startedTime': 1662000558293,
#     'finishedTime': 1662000702530,
#     'elapsedTime': 144237,
#     'amContainerLogs': 'https://bmwdpdesp000254.advantagedp.org:8044/node/containerlogs/container_1660460142322_623425_01_000003/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000254.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 14757437,
#     'vcoreSeconds': 7081,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623662',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_b5644d6b-33c0-4a94-a43d-0182ede72f51',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623662/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '34c4d1b435604f61a2c12fa90331e93a',
#     'startedTime': 1662001155865,
#     'finishedTime': 1662001339685,
#     'elapsedTime': 183820,
#     'amContainerLogs': 'https://bmwdpdesp000229.advantagedp.org:8044/node/containerlogs/container_1660460142322_623662_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000229.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 29979972,
#     'vcoreSeconds': 14472,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623661',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_b5644d6b-33c0-4a94-a43d-0182ede72f51',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623661/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '4066f585eb4b482b9e36fd7beb0191de',
#     'startedTime': 1662001155742,
#     'finishedTime': 1662001341672,
#     'elapsedTime': 185930,
#     'amContainerLogs': 'https://bmwdpdesp000345.advantagedp.org:8044/node/containerlogs/container_1660460142322_623661_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000345.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 32758047,
#     'vcoreSeconds': 15829,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623660',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_b5644d6b-33c0-4a94-a43d-0182ede72f51',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623660/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'ff2613123031467ea5aa3718c188d8b7',
#     'startedTime': 1662001155583,
#     'finishedTime': 1662001336425,
#     'elapsedTime': 180842,
#     'amContainerLogs': 'https://bmwdpdesp000213.advantagedp.org:8044/node/containerlogs/container_1660460142322_623660_01_000003/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000213.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 29591437,
#     'vcoreSeconds': 14326,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623589',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_b8fee22c-3805-4d28-a35e-0182ed2f6682',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623589/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '4aef64c9038d4d69bc9781f982cf2739',
#     'startedTime': 1662000955348,
#     'finishedTime': 1662001243506,
#     'elapsedTime': 288158,
#     'amContainerLogs': 'https://bmwdpdesp000256.advantagedp.org:8044/node/containerlogs/container_1660460142322_623589_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000256.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 58557069,
#     'vcoreSeconds': 28370,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623583',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_5b1908e7-2cd5-434c-aa9a-0182ee11e3b7',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623583/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'aa887ea530ee4abca5507fd58c4c3819',
#     'startedTime': 1662000934062,
#     'finishedTime': 1662001303631,
#     'elapsedTime': 369569,
#     'amContainerLogs': 'https://bmwdpdesp000081.advantagedp.org:8044/node/containerlogs/container_1660460142322_623583_01_000016/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000081.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 74755579,
#     'vcoreSeconds': 36255,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623571',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_b5644d6b-33c0-4a94-a43d-0182ede72f51',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623571/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '67d7a5731b8c4472a43dd681a6ef5ce3',
#     'startedTime': 1662000911993,
#     'finishedTime': 1662001078837,
#     'elapsedTime': 166844,
#     'amContainerLogs': 'https://bmwdpdesp000226.advantagedp.org:8044/node/containerlogs/container_1660460142322_623571_01_000010/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000226.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 26642127,
#     'vcoreSeconds': 12879,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623570',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_9982abd5-9e0f-4533-a912-0182ee44a411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623570/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '80e52f3ccb6647e69a27651b4ebf8f1d',
#     'startedTime': 1662000911071,
#     'finishedTime': 1662001280579,
#     'elapsedTime': 369508,
#     'amContainerLogs': 'https://bmwdpdesp000226.advantagedp.org:8044/node/containerlogs/container_1660460142322_623570_01_000009/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000226.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 68653804,
#     'vcoreSeconds': 33291,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623582',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_bbb8818e-3d5f-4f4a-abfb-0182edd80abe',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623582/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '13d9796627934bd6aafe7ec23b4ef4b7',
#     'startedTime': 1662000933765,
#     'finishedTime': 1662001228320,
#     'elapsedTime': 294555,
#     'amContainerLogs': 'https://bmwdpdesp000226.advantagedp.org:8044/node/containerlogs/container_1660460142322_623582_01_000015/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000226.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 57677954,
#     'vcoreSeconds': 27960,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623806',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_0bfd06a8-5410-4275-ae16-0182ee144fd0',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623806/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '5f23509fc1e0485597a75719bc816a51',
#     'startedTime': 1662001564730,
#     'finishedTime': 1662001740309,
#     'elapsedTime': 175579,
#     'amContainerLogs': 'https://bmwdpdesp000063.advantagedp.org:8044/node/containerlogs/container_1660460142322_623806_01_000003/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000063.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 27555615,
#     'vcoreSeconds': 13308,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623799',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_9a40cbe9-a6b7-4b15-abcd-0182eed9801d',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623799/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'b2f8fff734e14b52916748bb9b5c9636',
#     'startedTime': 1662001546155,
#     'finishedTime': 1662002440084,
#     'elapsedTime': 893929,
#     'amContainerLogs': 'https://bmwdpdesp000096.advantagedp.org:8044/node/containerlogs/container_1660460142322_623799_01_000004/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000096.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 183257933,
#     'vcoreSeconds': 88940,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_623760',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_4d802236-3dce-4df7-aff6-0182ed756252',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_623760/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '9bbb36a12f284f1da862dd27e56bde08',
#     'startedTime': 1662001400221,
#     'finishedTime': 1662001566942,
#     'elapsedTime': 166721,
#     'amContainerLogs': 'https://bmwdpdesp000294.advantagedp.org:8044/node/containerlogs/container_1660460142322_623760_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000294.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 25768854,
#     'vcoreSeconds': 12465,
# ...
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '5ceefb5878084225a39da4626cd6ef25',
#     'startedTime': 1662007453848,
#     'finishedTime': 1662007551818,
#     'elapsedTime': 97970,
#     'amContainerLogs': 'https://bmwdpdesp000248.advantagedp.org:8044/node/containerlogs/container_1660460142322_626360_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000248.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 18145777,
#     'vcoreSeconds': 8750,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626341',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_83cf02ea-b4f4-4ec1-aac8-0182eef7058b',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626341/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '1f92e9e5590343cda91340815cfd307e',
#     'startedTime': 1662007411097,
#     'finishedTime': 1662007514014,
#     'elapsedTime': 102917,
#     'amContainerLogs': 'https://bmwdpdesp000310.advantagedp.org:8044/node/containerlogs/container_1660460142322_626341_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000310.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 14964633,
#     'vcoreSeconds': 7201,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626340',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_83cf02ea-b4f4-4ec1-aac8-0182eef7058b',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626340/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '90ae5de2474a49a1a704e5663e5e8985',
#     'startedTime': 1662007411318,
#     'finishedTime': 1662007545410,
#     'elapsedTime': 134092,
#     'amContainerLogs': 'https://bmwdpdesp000115.advantagedp.org:8044/node/containerlogs/container_1660460142322_626340_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000115.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 16866586,
#     'vcoreSeconds': 8139,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626339',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_24239b56-5de3-4ce3-ad3b-0182ee1eb506',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626339/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'c5ab675f4b9a4b6f94e148165cc22022',
#     'startedTime': 1662007411088,
#     'finishedTime': 1662007535642,
#     'elapsedTime': 124554,
#     'amContainerLogs': 'https://bmwdpdesp000095.advantagedp.org:8044/node/containerlogs/container_1660460142322_626339_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000095.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 19526672,
#     'vcoreSeconds': 9410,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626338',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_83cf02ea-b4f4-4ec1-aac8-0182eef7058b',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626338/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'a9d452477af04befa5ce8bc6cd99824e',
#     'startedTime': 1662007410763,
#     'finishedTime': 1662007544022,
#     'elapsedTime': 133259,
#     'amContainerLogs': 'https://bmwdpdesp000210.advantagedp.org:8044/node/containerlogs/container_1660460142322_626338_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000210.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 20962588,
#     'vcoreSeconds': 10118,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626310',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-sensor-calibration_99bcf53b-7401-446c-a673-0182ef1b5836',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626310/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '22b7629f193c43d394d22a68620642b2',
#     'startedTime': 1662007324005,
#     'finishedTime': 1662007439971,
#     'elapsedTime': 115966,
#     'amContainerLogs': 'https://bmwdpdesp000240.advantagedp.org:8044/node/containerlogs/container_1660460142322_626310_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000240.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 17469406,
#     'vcoreSeconds': 8406,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626309',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync_99bcf53b-7401-446c-a673-0182ef1b5836',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626309/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'f6bf70f363364cdd8e421962ddfeeaf6',
#     'startedTime': 1662007323956,
#     'finishedTime': 1662007460031,
#     'elapsedTime': 136075,
#     'amContainerLogs': 'https://bmwdpdesp000079.advantagedp.org:8044/node/containerlogs/container_1660460142322_626309_01_000004/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000079.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 21662975,
#     'vcoreSeconds': 10453,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626311',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-timesync-parquet_99bcf53b-7401-446c-a673-0182ef1b5836',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626311/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '4d3aa9b9e75b4003a8b473c8bc18f24c',
#     'startedTime': 1662007324067,
#     'finishedTime': 1662007465054,
#     'elapsedTime': 140987,
#     'amContainerLogs': 'https://bmwdpdesp000080.advantagedp.org:8044/node/containerlogs/container_1660460142322_626311_01_000005/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000080.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 22687869,
#     'vcoreSeconds': 10952,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626296',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_867647e8-721d-45d6-a2a4-0182eea38549',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626296/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '8aea508119cb483c9519a169320ed55f',
#     'startedTime': 1662007281021,
#     'finishedTime': 1662007394686,
#     'elapsedTime': 113665,
#     'amContainerLogs': 'https://bmwdpdesp000350.advantagedp.org:8044/node/containerlogs/container_1660460142322_626296_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000350.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 17251332,
#     'vcoreSeconds': 8347,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626273',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata-store_564ed734-ea86-425a-ad72-0182edd55aa3',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626273/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '721afdd7d1c440bdb24b66fb22a73499',
#     'startedTime': 1662007236448,
#     'finishedTime': 1662007528749,
#     'elapsedTime': 292301,
#     'amContainerLogs': 'https://bmwdpdesp000049.advantagedp.org:8044/node/containerlogs/container_1660460142322_626273_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000049.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 57326840,
#     'vcoreSeconds': 27807,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626272',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_bc2fc3bf-48d9-49a7-a9d9-0182ee588411',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626272/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'cbc8105a141241b6ae352b72e7ca225d',
#     'startedTime': 1662007236281,
#     'finishedTime': 1662007323204,
#     'elapsedTime': 86923,
#     'amContainerLogs': 'https://bmwdpdesp000344.advantagedp.org:8044/node/containerlogs/container_1660460142322_626272_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000344.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 14556340,
#     'vcoreSeconds': 7024,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626271',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-attachments_982e1884-3d53-4eb5-adf0-0182ef46b16a',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626271/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '50e85f9cb04e48f08bb19e588b64937a',
#     'startedTime': 1662007235951,
#     'finishedTime': 1662007313205,
#     'elapsedTime': 77254,
#     'amContainerLogs': 'https://bmwdpdesp000174.advantagedp.org:8044/node/containerlogs/container_1660460142322_626271_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000174.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12468189,
#     'vcoreSeconds': 6012,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626283',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_65977e1e-8def-4dd5-af5e-0182ef2d50d9',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626283/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': '5ccd3793d199497cb1073bab15df981b',
#     'startedTime': 1662007259275,
#     'finishedTime': 1662007363261,
#     'elapsedTime': 103986,
#     'amContainerLogs': 'https://bmwdpdesp000100.advantagedp.org:8044/node/containerlogs/container_1660460142322_626283_01_000001/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000100.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 12883896,
#     'vcoreSeconds': 6195,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0},
#    {'id': 'application_1660460142322_626263',
#     'user': 'ingest_pipeline-s',
#     'name': 'SessionIngestJob-session-metadata_83cf02ea-b4f4-4ec1-aac8-0182eef7058b',
#     'queue': 'root.projects.project_ingest_pipeline_processing',
#     'state': 'FINISHED',
#     'finalStatus': 'SUCCEEDED',
#     'progress': 100.0,
#     'trackingUI': 'History',
#     'trackingUrl': 'https://bmwdpmesp000006.advantagedp.org:8090/proxy/application_1660460142322_626263/',
#     'diagnostics': '',
#     'clusterId': 1660460142322,
#     'applicationType': 'SPARK',
#     'applicationTags': 'f7815c108580462498c64f849c0d06e7',
#     'startedTime': 1662007212729,
#     'finishedTime': 1662007297849,
#     'elapsedTime': 85120,
#     'amContainerLogs': 'https://bmwdpdesp000052.advantagedp.org:8044/node/containerlogs/container_1660460142322_626263_01_000002/ingest_pipeline-s',
#     'amHostHttpAddress': 'bmwdpdesp000052.advantagedp.org:8044',
#     'allocatedMB': -1,
#     'allocatedVCores': -1,
#     'runningContainers': -1,
#     'memorySeconds': 13174506,
#     'vcoreSeconds': 6373,
#     'preemptedResourceMB': 0,
#     'preemptedResourceVCores': 0,
#     'numNonAMContainerPreempted': 0,
#     'numAMContainerPreempted': 0}]}}

# %%
names, ids, trackingUrls, diagnostics, queues = zip(
     *(
         (
            item["name"],
            item["id"],
            item["trackingUrl"],
            item["diagnostics"],
            item["queue"],
        )
        for item in response_json["apps"]["app"]
    )
)

# %%
df = pd.DataFrame(
    {
        "Names": names,
        "Ids": ids,
        "TrackingUrls": trackingUrls,
        "Diagnostics": diagnostics,
        "Queues": queues,
    }
)

# %%
df
# Out:
#                                                  Names  \
# 0    SessionIngestJob-timesync_bbb8818e-3d5f-4f4a-a...
# 1    SessionIngestJob-sensor-calibration_bbb8818e-3...
# 2    SessionIngestJob-timesync-parquet_bbb8818e-3d5...
# 3    SessionIngestJob-timesync_5b1908e7-2cd5-434c-a...
# 4    SessionIngestJob-timesync-parquet_9982abd5-9e0...
# ..                                                 ...
# 862  SessionIngestJob-session-metadata-store_564ed7...
# 863  SessionIngestJob-session-metadata_bc2fc3bf-48d...
# 864  SessionIngestJob-attachments_982e1884-3d53-4eb...
# 865  SessionIngestJob-session-metadata_65977e1e-8de...
# 866  SessionIngestJob-session-metadata_83cf02ea-b4f...
#
#                                   Ids  \
# 0    application_1660460142322_623414
# 1    application_1660460142322_623413
# 2    application_1660460142322_623415
# 3    application_1660460142322_623398
# 4    application_1660460142322_623397
# ..                                ...
# 862  application_1660460142322_626273
# 863  application_1660460142322_626272
# 864  application_1660460142322_626271
# 865  application_1660460142322_626283
# 866  application_1660460142322_626263
#
#                                           TrackingUrls Diagnostics  \
# 0    https://bmwdpmesp000006.advantagedp.org:8090/p...
# 1    https://bmwdpmesp000006.advantagedp.org:8090/p...
# 2    https://bmwdpmesp000006.advantagedp.org:8090/p...
# 3    https://bmwdpmesp000006.advantagedp.org:8090/p...
# 4    https://bmwdpmesp000006.advantagedp.org:8090/p...
# ..                                                 ...         ...
# 862  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 863  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 864  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 865  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 866  https://bmwdpmesp000006.advantagedp.org:8090/p...
#
#                                                Queues
# 0    root.projects.project_ingest_pipeline_processing
# 1    root.projects.project_ingest_pipeline_processing
# 2    root.projects.project_ingest_pipeline_processing
# 3    root.projects.project_ingest_pipeline_processing
# 4    root.projects.project_ingest_pipeline_processing
# ..                                                ...
# 862  root.projects.project_ingest_pipeline_processing
# 863  root.projects.project_ingest_pipeline_processing
# 864  root.projects.project_ingest_pipeline_processing
# 865  root.projects.project_ingest_pipeline_processing
# 866  root.projects.project_ingest_pipeline_processing
#
# [867 rows x 5 columns]

# %%
names2, ids2, trackingUrls2, diagnostics2, queues2 = zip(
     *(
         (
            item["name"],
            item["id"],
            item["trackingUrl"],
            item["diagnostics"],
            item["queue"],
        )
        for item in response2_json["apps"]["app"]
    )
)

# %%
df2 = pd.DataFrame(
    {
        "Names": names2,
        "Ids": ids2,
        "TrackingUrls": trackingUrls2,
        "Diagnostics": diagnostics2,
        "Queues": queues2,
    }
)

# %%
df2
# Out:
#                         Names                               Ids  \
# 0           SessionCheckerJob  application_1660460142322_623729
# 1           SessionCheckerJob  application_1660460142322_622927
# 2           SessionCheckerJob  application_1660460142322_624814
# 3           SessionCheckerJob  application_1660460142322_624311
# 4  SessionCheckerJob-reingest  application_1660460142322_631343
# 5           SessionCheckerJob  application_1660460142322_627664
# 6           SessionCheckerJob  application_1660460142322_626919
# 7           SessionCheckerJob  application_1660460142322_625807
# 8           SessionCheckerJob  application_1660460142322_626371
#
#                                         TrackingUrls Diagnostics  \
# 0  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 1  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 2  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 3  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 4  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 5  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 6  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 7  https://bmwdpmesp000006.advantagedp.org:8090/p...
# 8  https://bmwdpmesp000006.advantagedp.org:8090/p...
#
#                                             Queues
# 0            root.projects.project_session_checker
# 1            root.projects.project_session_checker
# 2            root.projects.project_session_checker
# 3            root.projects.project_session_checker
# 4  root.projects_irregular.project_session_checker
# 5            root.projects.project_session_checker
# 6            root.projects.project_session_checker
# 7            root.projects.project_session_checker
# 8            root.projects.project_session_checker

# %%
url3 = 'https://api.devops.advantagedp.org:6443/version'
auth3 = HTTPBasicAuth('devops_apps_pol-s', 'k1.oandvaL3Q7ydJ')

# %%
response3 = requests.get(url3, auth=auth3, proxies=proxies, verify=False)
response_json3 = response3.json()
response3
# Out:
# <Response [200]>

# %%
response_json3
# Out:
# {'major': '1',
#  'minor': '21',
#  'gitVersion': 'v1.21.6+b82a451',
#  'gitCommit': 'cefce093e4e5bc9a1916eb5a489ed37c7d467f6f',
#  'gitTreeState': 'clean',
#  'buildDate': '2022-02-05T06:58:30Z',
#  'goVersion': 'go1.16.6',
#  'compiler': 'gc',
#  'platform': 'linux/amd64'}
