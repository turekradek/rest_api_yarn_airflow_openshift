# %%
import pandas as pd

# %%
plik = open('bbbb.txt','r')
a = plik.read()
plik.close()
print(type(a), len(a))
# Out:
# <class 'str'> 412802

# %%
import json

# %%
b = a.replace(r'''"items": [
    {
      "metadata": {
        "name":''', '''****"items": [
    {
      "metadata": {
        "name":''')

# %%
# print(b)
c = b.split('***')
print( len(c) )
# Out:
# 2

# %%
import a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/radekt/git_projekty/rest_api_yarn/a.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bdebian/home/radekt/git_projekty/rest_api_yarn/a.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import a
#
# File ~/git_projekty/rest_api_yarn/a.py:31, in <module>
#       1 slownik = {
#       2   "kind": "PodList",
#       3   "apiVersion": "v1",
#       4   "metadata": {
#       5     "resourceVersion": "2653193340"
#       6   },
#       7   "items": [
#       8     {
#       9       "metadata": {
#      10         "name": "dpm-cron-aggregate-27699237-drxqn",
#      11         "generateName": "dpm-cron-aggregate-27699237-",
#      12         "namespace": "data-pipeline-monitoring-prod",
#      13         "uid": "892b6fed-f024-4669-abd3-5937f1a4b015",
#      14         "resourceVersion": "2653164291",
# ...
